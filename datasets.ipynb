# %%
# installing the required module
# !pip install transformers

# %%
# installing datasets
# !pip install datasets

# %%
# !pip install SentencePiece

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/iris.csv.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail(15)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 135           7.7          3.0           6.1          2.3  Virginica
# 136           6.3          3.4           5.6          2.4  Virginica
# 137           6.4          3.1           5.5          1.8  Virginica
# 138           6.0          3.0           4.8          1.8  Virginica
# 139           6.9          3.1           5.4          2.1  Virginica
# 140           6.7          3.1           5.6          2.4  Virginica
# 141           6.9          3.1           5.1          2.3  Virginica
# 142           5.8          2.7           5.1          1.9  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# ...

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # loading only one specific coloumn

# %%
df["sepal.width"].describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal.width, dtype: float64

# %% [markdown]
# # data on specific location

# %%
df.iloc[125]
# Out:
# sepal.length          7.2
# sepal.width           3.2
# petal.length          6.0
# petal.width           1.8
# variety         Virginica
# Name: 125, dtype: object

# %%
df.iloc[""]    # it will bring name files which will be in left side but in dis dataset , its only sorted out via numbers

df.sort_values[by = "year"].head
   #year is dummy data for this set, it will sort by year nd cux of head it will give only 5 rows

# %%
df.sort_values[by = "year" , ascending=false].head   #year is dummy data for this set, it will sort by year nd cux of head it will give only 5 rows

# %%
df[df["sepal.width"]== 2.3]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 41           4.5          2.3           1.3          0.3      Setosa
# 53           5.5          2.3           4.0          1.3  Versicolor
# 87           6.3          2.3           4.4          1.3  Versicolor
# 93           5.0          2.3           3.3          1.0  Versicolor

# %%
above_width = df["sepal.width"] >2.5
df[above_width]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [131 rows x 5 columns]

# %%
above_width = df["sepal.width"].between(2,3)
df[above_width]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# 13            4.3          3.0           1.1          0.1     Setosa
# 25            5.0          3.0           1.6          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 142           5.8          2.7           5.1          1.9  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [83 rows x 5 columns]

# %%
import pandas as pd
import numpy as np      #visualization
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)

# %% [markdown]
# # loading dataset

# %%
df = pd.read_csv("/content/video_games (1).csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4bb6197a8ec> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/video_games (1).csv")
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#                       Title  Features.Handheld?  Features.Max Players  \
# 0         Super Mario 64 DS                True                     1
# 1    Lumines: Puzzle Fusion                True                     1
# 2        WarioWare Touched!                True                     2
# 3  Hot Shots Golf: Open Tee                True                     1
# 4              Spider-Man 2                True                     1
#
#    Features.Multiplatform?  Features.Online?                 Metadata.Genres  \
# 0                     True              True                          Action
# 1                     True              True                        Strategy
# 2                     True              True  Action,Racing / Driving,Sports
# 3                     True              True                          Sports
# 4                     True              True                          Action
#
#    Metadata.Licensed? Metadata.Publishers  Metadata.Sequel?  \
# ...

# %% [markdown]
# # dropping coloumn by using axis function , it will drop whole coloumn

# %%
df = df.drop(["Features.Max Players"],axis=1)

# %%
df.head()
# Out:
#                       Title  Features.Handheld?  Features.Multiplatform?  \
# 0         Super Mario 64 DS                True                     True
# 1    Lumines: Puzzle Fusion                True                     True
# 2        WarioWare Touched!                True                     True
# 3  Hot Shots Golf: Open Tee                True                     True
# 4              Spider-Man 2                True                     True
#
#    Features.Online?                 Metadata.Genres  Metadata.Licensed?  \
# 0              True                          Action                True
# 1              True                        Strategy                True
# 2              True  Action,Racing / Driving,Sports                True
# 3              True                          Sports                True
# 4              True                          Action                True
#
#   Metadata.Publishers  Metadata.Sequel?  Metrics.Review Score  Metrics.Sales  \
# ...

# %%
df = df.rename(columns={"Features.Handheld?" : "fp","Features.Multiplatform?" : "fm"})
df.head()
# Out:
#                       Title    fp    fm  Features.Online?  \
# 0         Super Mario 64 DS  True  True              True
# 1    Lumines: Puzzle Fusion  True  True              True
# 2        WarioWare Touched!  True  True              True
# 3  Hot Shots Golf: Open Tee  True  True              True
# 4              Spider-Man 2  True  True              True
#
#                   Metadata.Genres  Metadata.Licensed? Metadata.Publishers  \
# 0                          Action                True            Nintendo
# 1                        Strategy                True             Ubisoft
# 2  Action,Racing / Driving,Sports                True            Nintendo
# 3                          Sports                True                Sony
# 4                          Action                True          Activision
#
#    Metadata.Sequel?  Metrics.Review Score  Metrics.Sales  ...  \
# 0              True                    85           4.69  ...
# ...

# %% [markdown]
# # checking duplicate rows

# %%
df.shape
# Out:
# (1212, 35)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicated rows = " ,duplicate_rows_df )
# Out:
# number of duplicated rows =  Empty DataFrame
# Columns: [Title, fp, fm, Features.Online?, Metadata.Genres, Metadata.Licensed?, Metadata.Publishers, Metadata.Sequel?, Metrics.Review Score, Metrics.Sales, Metrics.Used Price, Release.Console, Release.Rating, Release.Re-release?, Release.Year, Length.All PlayStyles.Average, Length.All PlayStyles.Leisure, Length.All PlayStyles.Median, Length.All PlayStyles.Polled, Length.All PlayStyles.Rushed, Length.Completionists.Average, Length.Completionists.Leisure, Length.Completionists.Median, Length.Completionists.Polled, Length.Completionists.Rushed, Length.Main + Extras.Average, Length.Main + Extras.Leisure, Length.Main + Extras.Median, Length.Main + Extras.Polled, Length.Main + Extras.Rushed, Length.Main Story.Average, Length.Main Story.Leisure, Length.Main Story.Median, Length.Main Story.Polled, Length.Main Story.Rushed]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.count()
# Out:
# Title                            1212
# fp                               1212
# fm                               1212
# Features.Online?                 1212
# Metadata.Genres                  1212
# Metadata.Licensed?               1212
# Metadata.Publishers               948
# Metadata.Sequel?                 1212
# Metrics.Review Score             1212
# Metrics.Sales                    1212
# Metrics.Used Price               1212
# Release.Console                  1212
# Release.Rating                   1212
# Release.Re-release?              1212
# Release.Year                     1212
# Length.All PlayStyles.Average    1212
# Length.All PlayStyles.Leisure    1212
# Length.All PlayStyles.Median     1212
# Length.All PlayStyles.Polled     1212
# Length.All PlayStyles.Rushed     1212
# Length.Completionists.Average    1212
# Length.Completionists.Leisure    1212
# Length.Completionists.Median     1212
# Length.Completionists.Polled     1212
# Length.Completionists.Rushed     1212
# ...

# %% [markdown]
# # drop duplicate rows if there is any but in this dataset , there is no duplicate row

# %%
df = df.drop_duplicates()
df.head()
# Out:
#                       Title    fp    fm  Features.Online?  \
# 0         Super Mario 64 DS  True  True              True
# 1    Lumines: Puzzle Fusion  True  True              True
# 2        WarioWare Touched!  True  True              True
# 3  Hot Shots Golf: Open Tee  True  True              True
# 4              Spider-Man 2  True  True              True
#
#                   Metadata.Genres  Metadata.Licensed? Metadata.Publishers  \
# 0                          Action                True            Nintendo
# 1                        Strategy                True             Ubisoft
# 2  Action,Racing / Driving,Sports                True            Nintendo
# 3                          Sports                True                Sony
# 4                          Action                True          Activision
#
#    Metadata.Sequel?  Metrics.Review Score  Metrics.Sales  ...  \
# 0              True                    85           4.69  ...
# ...

# %% [markdown]
# # dropping the missing nd null values

# %%
df.count()
# Out:
# Title                            1212
# fp                               1212
# fm                               1212
# Features.Online?                 1212
# Metadata.Genres                  1212
# Metadata.Licensed?               1212
# Metadata.Publishers               948
# Metadata.Sequel?                 1212
# Metrics.Review Score             1212
# Metrics.Sales                    1212
# Metrics.Used Price               1212
# Release.Console                  1212
# Release.Rating                   1212
# Release.Re-release?              1212
# Release.Year                     1212
# Length.All PlayStyles.Average    1212
# Length.All PlayStyles.Leisure    1212
# Length.All PlayStyles.Median     1212
# Length.All PlayStyles.Polled     1212
# Length.All PlayStyles.Rushed     1212
# Length.Completionists.Average    1212
# Length.Completionists.Leisure    1212
# Length.Completionists.Median     1212
# Length.Completionists.Polled     1212
# Length.Completionists.Rushed     1212
# ...

# %%
print(df.isnull().sum())
# Out:
# Title                              0
# fp                                 0
# fm                                 0
# Features.Online?                   0
# Metadata.Genres                    0
# Metadata.Licensed?                 0
# Metadata.Publishers              264
# Metadata.Sequel?                   0
# Metrics.Review Score               0
# Metrics.Sales                      0
# Metrics.Used Price                 0
# Release.Console                    0
# Release.Rating                     0
# Release.Re-release?                0
# Release.Year                       0
# Length.All PlayStyles.Average      0
# Length.All PlayStyles.Leisure      0
# Length.All PlayStyles.Median       0
# Length.All PlayStyles.Polled       0
# Length.All PlayStyles.Rushed       0
# Length.Completionists.Average      0
# Length.Completionists.Leisure      0
# Length.Completionists.Median       0
# Length.Completionists.Polled       0
# Length.Completionists.Rushed       0
# ...

# %%
df = df.dropna()            # dropping null values

# %%
df.count()
# Out:
# Title                            948
# fp                               948
# fm                               948
# Features.Online?                 948
# Metadata.Genres                  948
# Metadata.Licensed?               948
# Metadata.Publishers              948
# Metadata.Sequel?                 948
# Metrics.Review Score             948
# Metrics.Sales                    948
# Metrics.Used Price               948
# Release.Console                  948
# Release.Rating                   948
# Release.Re-release?              948
# Release.Year                     948
# Length.All PlayStyles.Average    948
# Length.All PlayStyles.Leisure    948
# Length.All PlayStyles.Median     948
# Length.All PlayStyles.Polled     948
# Length.All PlayStyles.Rushed     948
# Length.Completionists.Average    948
# Length.Completionists.Leisure    948
# Length.Completionists.Median     948
# Length.Completionists.Polled     948
# Length.Completionists.Rushed     948
# ...

# %%
print(df.isnull().sum())
# Out:
# Title                            0
# fp                               0
# fm                               0
# Features.Online?                 0
# Metadata.Genres                  0
# Metadata.Licensed?               0
# Metadata.Publishers              0
# Metadata.Sequel?                 0
# Metrics.Review Score             0
# Metrics.Sales                    0
# Metrics.Used Price               0
# Release.Console                  0
# Release.Rating                   0
# Release.Re-release?              0
# Release.Year                     0
# Length.All PlayStyles.Average    0
# Length.All PlayStyles.Leisure    0
# Length.All PlayStyles.Median     0
# Length.All PlayStyles.Polled     0
# Length.All PlayStyles.Rushed     0
# Length.Completionists.Average    0
# Length.Completionists.Leisure    0
# Length.Completionists.Median     0
# Length.Completionists.Polled     0
# Length.Completionists.Rushed     0
# Length.Main + Extras.Average     0
# Length.Main + Extras.Leisure     0
# ...

# %% [markdown]
# # Detecting outliers

# %%
df.shape
# Out:
# (891, 12)

# %%
sns.boxplot(x=df[ "Metrics.Review Score" ])
# Out:
# <Axes: xlabel='Metrics.Review Score'>

# %%
sns.boxplot(x=df[""])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WarioWare Touched!'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ### will try iqr method on another dataset , as its giving error in dis

# %%
df.describe()
# Out:
#        Metrics.Review Score  Metrics.Sales  Metrics.Used Price  Release.Year  \
# count            948.000000     948.000000          948.000000    948.000000
# mean              69.681435       0.562099           17.335021   2006.746835
# std               12.739357       1.173686            5.182464      1.059597
# min               25.000000       0.010000            4.950000   2004.000000
# 25%               61.750000       0.110000           14.950000   2006.000000
# 50%               71.000000       0.250000           16.950000   2007.000000
# 75%               80.000000       0.500000           17.950000   2008.000000
# max               98.000000      14.660000           49.950000   2008.000000
#
#        Length.All PlayStyles.Average  Length.All PlayStyles.Leisure  \
# count                     948.000000                     948.000000
# mean                       13.561094                      25.469532
# std                        20.066423                      47.401659
# ...

# %%
df.corr()
# Out:
# <ipython-input-21-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                fp  fm  Features.Online?  Metadata.Licensed?  \
# fp                            NaN NaN               NaN                 NaN
# fm                            NaN NaN               NaN                 NaN
# Features.Online?              NaN NaN               NaN                 NaN
# Metadata.Licensed?            NaN NaN               NaN                 NaN
# Metadata.Sequel?              NaN NaN               NaN                 NaN
# Metrics.Review Score          NaN NaN               NaN                 NaN
# Metrics.Sales                 NaN NaN               NaN                 NaN
# Metrics.Used Price            NaN NaN               NaN                 NaN
# ...

# %% [markdown]
# # Titanic Dataset analysis

# %%
df = pd.read_csv("/content/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
iqr = q3 - q1
print(iqr)
# Out:
# PassengerId    445.0000
# Survived         1.0000
# Pclass           1.0000
# Age             17.8750
# SibSp            1.0000
# Parch            0.0000
# Fare            23.0896
# dtype: float64
# <ipython-input-5-9f108d2d3a31>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q1 = df.quantile(0.25)
# <ipython-input-5-9f108d2d3a31>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q3 = df.quantile(0.75)

# %%
df.corr()
# Out:
# <ipython-input-6-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %% [markdown]
# # Heatmaps

# %%
# adjusting the size of figure
plt.figure(figsize=(10,5))
# calculating correlation
correlation = df.corr()
# displaying the correlation using heatmap
sns.heatmap(correlation, annot = True)
# Out:
# <ipython-input-7-bf50c41f90af>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()
# <Axes: >

# %%
# ignore warnings
import warnings
# set the warning filter to ignore future warning
warnings.simplefilter(action="ignore",category = FutureWarning)

# %%
sns.histplot(df['Parch'],kde=False)
plt.show()

# %% [markdown]
# # kdeplot

# %%
sns.distplot(df['Age'])      # if we put hist=false , then it wont show lines in graph
plt.show()
# Out:
# <ipython-input-10-24d7b07f00dd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])      # if we put hist=false , then it wont show lines in graph

# %% [markdown]
# # Relationalplots
# relplot

# %%
sns.relplot(x="Age", y="Fare",hue="Sex",kind="line",col="Pclass",style="Sex" ,data=df)
plt.show()

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x="Age",y="Fare",hue="Sex",data=df)
plt.show()

# %%
sns.lineplot(x="Age",y="Fare",hue="Sex",data=df)   # with style,it will show dotted lines
plt.show()

# %%
sns.barplot(x="Age",y="Fare",hue="Sex",data=df)   # with style,it will show dotted lines
plt.show()

# %% [markdown]
# # categorical plot
# barplot

# %%
plt.figure(figsize=(9,8))
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=df)
sns.barplot(x='sex',y='survived',hue='fare',data=df)
plt.show()

# %% [markdown]
# # stripplot

# %%
sns.stripplot(x="Sex",y="Age",hue="Sex",data=df)
plt.show()

# %%
sns.violinplot(x="Sex",y="Age",hue="Sex",data=df)
plt.show()

# %%
sns.boxplot(x="Survived",y="Age",hue="Sex",data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x="Age",y="Sex",data=df)
plt.show()

# %%
sns.countplot(x="Survived",data=df)
plt.show()

# %%
sns.regplot(x="Age",y="Fare",data=df)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-8-f6412ee67fb3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
g = sns.FacetGrid(df ,col= "Survived" , row="Pclass")
g.map(plt.hist, "Age")
g.add_legend()
plt.show()

# %% [markdown]
# # lecture 15

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
# data shape
print("train data :" ,df.shape)
# Out:
# train data : (891, 12)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#heatmap

sns.heatmap(df.isnull() , yticklabels= False , cbar=False , cmap="tab20c_r" )   #yticklabels will del y coloumn,cbar will dell side color palate of heatmap , cmap will define color
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x="Pclass",y="Age",data = df,palette = "GnBu_d" )
plt.title("Age by passenger class")
plt.show()

# %%
# imputation function

def impute_age(cols):
  Age = cols[0]
  Pclass = cols[1]

  if pd.isnull(Age):

    if Pclass ==1:
      return 37

    elif Pclass ==2:
        return 29
    else:
        return 24

  else:
    return Age


# apply the function to the age coloumn

# %%
df['Age']=df[['Age','Pclass']].apply(impute_age , axis=1)

# %% [markdown]
# the cabin coloumn has too many missing values to do anything useful with , so it would be best to remove it from data

# %%
df.drop('Cabin',axis=1,inplace= True) #inplace is used for not showing dataframe

# %%
# remove rows with missing data
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# remove unnecessary columns
df.drop(['Name','Ticket'],axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  24.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %% [markdown]
# converting gender and embarked objects into category type as male female is category and embarked is showing from which place they are , so its category as well

# %%
df.drop(['Name','Ticket'],axis=1,inplace=True)

# %%
#convert objects to category data type
objcat= ['Sex','Embarked']

for colname in objcat:
  df[colname] = df[colname].astype('category')

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  24.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
# remove passenger id , as it cannot save anyone
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  24.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# # Getting model ready

# %%
# shape of train data
df.shape
# Out:
# (891, 9)

# %%
# identify categorical columns
df.select_dtypes(['category']).columns
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
# convert categorical variables into 'dummy' or indicator variables
sex = pd.get_dummies(df['Sex'])
embarked = pd.get_dummies(df['Embarked'])

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# now here still embarked column doesnt have dummy values , so we will use concT FUNCTION

# %%
df = pd.concat([df,sex,embarked],axis=1)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  female  male  C  Q  S
# 0        S       0     1  0  0  1
# 1        C       1     0  1  0  0
# 2        S       1     0  0  0  1
# 3        S       1     0  0  0  1
# 4        S       0     1  0  0  1

# %%
df.drop('PassengerId',axis=1)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  female  male  C  Q  S
# 0        S       0     1  0  0  1
# 1        C       1     0  1  0  0
# 2        S       1     0  0  0  1
# 3        S       1     0  0  0  1
# 4        S       0     1  0  0  1

# %%
# drop unnecessary coloumns
df.drop(['Sex', 'Embarked'],axis=1,inplace=True)

# shape of train data

print('train_data shape ' , df.shape)

# confirm changes

df.head()
# Out:
# train_data shape  (891, 12)
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  female  male  \
# 0            1         0       3  22.0      1      0   7.2500       0     1
# 1            2         1       1  38.0      1      0  71.2833       1     0
# 2            3         1       3  26.0      0      0   7.9250       1     0
# 3            4         1       1  35.0      1      0  53.1000       1     0
# 4            5         0       3  35.0      0      0   8.0500       0     1
#
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
df.drop(['PassengerId' , 'female'],axis= 1 , inplace = True)
df.head(5)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  C  Q  S
# 0         0       3  22.0      1      0   7.2500     1  0  0  1
# 1         1       1  38.0      1      0  71.2833     0  1  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  0  1
# 4         0       3  35.0      0      0   8.0500     1  0  0  1

# %%
df.drop(['C'] , axis = 1 , inplace = True)

# %%
df.head(5)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         0       3  22.0      1      0   7.2500     1  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  1
# 4         0       3  35.0      0      0   8.0500     1  0  1

# %%
#split data to be used in module
# create matrix of features

x = df.drop('Survived',axis = 1)

# create target variable

y = df['Survived']

# use x and y variables to split the training data into train and test data

from sklearn.linear_model import train_test_split

x_train,x_test,y_train,y_test

# %%
import

# %%
import cv2

# %%
img = cv2.imread("/content/dimension.jpeg")

# %%
# !pip install pillow
# !pip install pill
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement pill (from versions: none)
# ERROR: No matching distribution found for pill

# %%
from PIL import Image
img = Image.open("/content/dimension.jpeg")
width,height = img.size
print(f'the image dimensions are : {width}x{height}')
# Out:
# the image dimensions are : 576x953

# %%
from PIL import Image
import math

# Open the image file
img = Image.open('/content/D-1.jpeg')

# Get the width and height
width, height = img.size

# Calculate the diagonal length
diagonal = math.sqrt(width*2 + height*2)

print(f'Width: {width/96}')
print(f'Height: {height/96}')
print(f'Diagonal Length: {diagonal/96}')
# Out:
# Width: 7.520833333333333
# Height: 4.104166666666667
# Diagonal Length: 0.49212549212573814

# %%
a = ' hello world'
print(a)
# Out:
#  hello world

# %%
print(a.upper())
# Out:
#  HELLO WORLD

# %%
print(a.lower())
# Out:
#  hello world

# %%
print(a.replace('hello','hi'))   #replacing words
# Out:
#  hi world

# %%
print(a.strip('l'))   #remove spaces
# Out:
#  hello world

# %%
print(a.capitalize())
# Out:
#  hello world

# %%
print(a.split(',')) #split breaks by dat integer
# Out:
# [' hello world']

# %%
print(a.swapcase())   #changes lower to upper nd vice versa
# Out:
#  HELLO WORLD

# %%
print(a.title())     #convert first letter of every word in uppercase
# Out:
#  Hello World

# %%
print(len(a))     #for finding length of all elements and count of single character or word
print(a.count('hello'))
# Out:
# 12
# 1

# %%
str1 = 'hello'
str2 = ' aroo'
#print(str1 + str2)

# %%
result = str1.concat(str2)
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-52373268e3ff> in <cell line: 1>()
# ----> 1 result = str1.concat(str2)
#       2 print(result)
#
# AttributeError: 'str' object has no attribute 'concat'

# %%
fruits = ['apple','banana', True , 34 ] # list is ordered , allows duplicate as well , allow indexing
print(fruits)
print(len(fruits))
print(fruits[2])
print(fruits[1:3])
fruits[0] ='orange'
print(fruits)
print(fruits[3])
fruits.append('mango')    #will add element on last
fruits.insert(2,76)  #will insert element on specific place
fruits.remove(34)  #will remove that element
print(fruits)
# Out:
# ['apple', 'banana', True, 34]
# 4
# True
# ['banana', True]
# ['orange', 'banana', True, 34]
# 34
# ['orange', 'banana', 76, True, 'mango']

# %%
tuple = ('apple','banana', True, 32 , 'apple')   #tuple is ordered , allows duplication and indexing but it cannot change the data
#print(tuple)
#print(len(tuple))
#print(tuple[1])
# tuple[1] = false
#tuple.append('mango')
#tuple.insert(2,76)   #commented methods arent allowed in tuple
#tuple.remove(32)
print(tuple)
print(tuple.count(True))

print(tuple[2])
# Out:
# ('apple', 'banana', True, 32, 'apple')
# 1
# True

# %%
set = { 1 ,1 ,' ayesha' , 'emala', 2.3}    #it ignores duplicate values , its unordered
print(set)
#set.count(1)
print(set)  #count cant work inset.remove('emala')
print(set.update({1:'hi'}))
print(set)
# Out:
# {1, 'emala', 2.3, ' ayesha'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-4d6e094b9d70> in <cell line: 3>()
#       1 set = { 1 ,1 ,' ayesha' , 'emala', 2.3}    #it ignores duplicate values , its unordered
#       2 print(set)
# ----> 3 set.count(1)
#       4 print(set)  #count cant work inset.remove('emala')
#       5 print(set.update({1:'hi'}))
#
# AttributeError: 'set' object has no attribute 'count'

# %%
#people_data = ''
for i in range(5):
  name = input('enter your name')
  age =int(input('enter your age'))
  if (age >= 25 and age <=35):
    print (name , 'is lecturer')
  elif (age >=35 and age <=45):
    print(name , ' is assistant professor')
  elif(age >= 45 and age <=55):
     print(name , ' is professor ')
  else:
     print(name , ' is not eligible')
# Out:
# enter your namea
# enter your age16
# a  is not eligible
# enter your namemaria
# enter your age78
# maria  is not eligible
# enter your name34
# enter your age76
# 34  is not eligible
# enter your namewahab
# enter your age38
# wahab  is assistant professor
# enter your namelaiba
# enter your age56
# laiba  is not eligible

# %%
# %%writefile my_program3.cpp
# #include<iostream>
# using namespace std;
# 	int sum(int num1 , int num2) {
#     return num1 + num2;
#   }
# int main (){
# 	int num1 , num2;
# 	cout<<"enter first number"<<endl;
# 	cin>>num1;
# 	cout<<"enter second number"<<endl;
# 	cin>>num2;
# 	cout<<sum(num1, num2);
# 	return 0;
# }
# Out:
# Overwriting my_program3.cpp

# %%
# %%writefile my_program2.cpp
# #include <iostream>
# using namespace std;
#
# int sum(int a, int b) {
#     return a + b;
# }
#
# int main() {
#     int result = sum(5, 3);
#     cout << "The sum is: " << result << endl;
#     return 0;
# }
# Out:
# Writing my_program2.cpp

# %%
# !g++ my_program3.cpp -o my_program3
# !./my_program3
# Out:
# enter first number
# ^C

# %%
# print values of  A in descending oder
num = 0

a = input ('enter a number')
while a >= num :
  print(a)
  a = a-2

# %%
# !pip install openai

# %%
import openai
#jo chiz ham ans k lye chah rhy hein , wo user waly mn likhein gy

# %%
openai.api_key = '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'
def sentiment_analysis(text):
  messages = [
      {'role':'system','content':'''you are trained to analyze and detect sentiment of given text , if you're unsure of an answer,  you can say ''Not sure '' and recommend user to check it manually'''},
      {'role':'user','content':f''' check if given text is positive or negative and return answer  in single word :{text}'''}
]
  response = openai.chat.completions.create(model='gpt-3.5-turbo',messages=messages,max_tokens=1,n=1,temperature=0)
  response_text = response.choices[0].message.content.strip().lower()
  return response_text

# %%
user = 'i hate food'
response = sentiment_analysis(user)
print (user ,': The sentiment is ', response)

# %%
# !pip install gemini
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 42.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 34.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 19.6 MB/s eta 0:00:00
# ...

# %%
AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f56ee851abac> in <cell line: 1>()
# ----> 1 AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk
#
# NameError: name 'AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk' is not defined

# %%
# !pip install  -q  -U google-generativeai

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import Markdown , display
def to_markdown(text):
  #text = text.replace('.' , '*')
  return Markdown(textwrap.indent(text, '>' , predicate=lambda _: True))

# %%
genai.configure(api_key= 'AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk')

# %%
def sentiment_analysis(text):
  genai.configure(api_key='AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk')
  messages = [
      {'role':'system' , 'content': 'you are trained model to analyze and detect sentiment of text'},
      {'role':'user', 'content':f'''check if the given text is positive or negative and return it in single word :{text}'''}
  ]
  sentiment_request = genai.sentimentRequest(text=text , model =genai.GenerativeModel(gemini-1.5-pro), max_tokens = 0 , temperature = 0 , n=1)
  response = genai_client.sentiment(sentiment_request)
  sentiment_label.lower()
  return sentiment_label

# %%
text = 'i am happy'
result = sentiment_analysis(text)
print(result)

# %%
import google.generativeai as genai
genai.configure(api_key= 'AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk' )
defaults = {
 'model': 'models/text-bison-001',
 'temperature': 0.5,
 'candidate_count': 1,
 'top_': 40,
 'top_p': 0.95,
 'max_output_tokens': 1,
}
prod_review=input('Enter you Feedback:')
prompt =f ''' What is the sentiment of the following sentence, which is delimited with triple backticks? Just give the sentiment in one word if it is positive, very positive, negative, very negative or neutral'''
Review text: '''{prod_review}'''
response = genai.generate_text(
 **defaults,
 prompt=prompt
)
print(response.result)
# Out:
#   File "<ipython-input-51-186a46ac7e1f>", line 12
#     prompt =f { ''' What is the sentiment of the following sentence, which is delimited with triple backticks? Just give the sentiment in one word if it is positive, very positive, negative, very negative or neutral'''},
#               ^
# SyntaxError: invalid syntax

# %%
# !pip install transformers

# %%
import transformers

# %%
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

# %%
from transformers import pipeline ,  set_api_key
set_api_key('AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk')
model_path = 'nlptown/bert-base-multilingual-uncased-sentiment'
sentiment_task = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)
sentiment_task("Covid cases are increasing fast!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-d8b6e7f2533d> in <cell line: 1>()
# ----> 1 from transformers import pipeline ,  set_api_key
#       2 set_api_key('AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk')
#       3 model_path = 'nlptown/bert-base-multilingual-uncased-sentiment'
#       4 sentiment_task = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)
#       5 sentiment_task("Covid cases are increasing fast!")
#
# ImportError: cannot import name 'set_api_key' from 'transformers' (/usr/local/lib/python3.10/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
# !pip install

# %%
#AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk

import google.generativeai as genai
import PIL.Image
import os

genai.configure("AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk")
img = PIL.Image.open('/content/cat')

model = genai.GenerativeModel(model_name="gemini-1.5-flash")
response = model.generate_content(["What is in this photo?", img])
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-65b8d4f40a86> in <cell line: 7>()
#       5 import os
#       6
# ----> 7 genai.configure("AIzaSyB83Vo7RQ801IjJZjSoT9W6Md7cAfrDKSk")
#       8 img = PIL.Image.open('/content/cat')
#       9
#
# TypeError: configure() takes 0 positional arguments but 1 positional argument (and 2 keyword-only arguments) were given

# %%
# !pip install langchain

# %%
# !pip install langchain langchain-community

# %% [markdown]
# ###pdf loader
# lets load a pdf

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 6.7 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader('/content/National AI Policy Consultation Draft V1.pdf')
pages = loader.load()

# %% [markdown]
# EACH page is a document ; A document contains text (page-content) and metadata.

# %%
len(pages)
# Out:
# 41

# %%
page = pages[0]

# %%
page
# Out:
# Document(metadata={'source': '/content/National AI Policy Consultation Draft V1.pdf', 'page': 0}, page_content=' \n \ni\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n                        Draft\nNational\n \nArtificial Intelligence Policy\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nGovernment of Pakistan\nMinistry of Information Technology & Telecommunication\nhttps://moitt.gov.pk\n \n \n \n')

# %%
print(page.page_content[0:800])    #it will give first 800 characters after adding spaces as well
# Out:
#
#
# i
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         Draft
# National
#
# Artificial Intelligence Policy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Government of Pakistan
# Ministry of Information Technology & Telecommunication
# https://moitt.gov.pk

# %%
page.metadata['page'] # from which page it came
# Out:
# 0

# %%
page.metadata['source'] #from which file it came
# Out:
# '/content/National AI Policy Consultation Draft V1.pdf'

# %% [markdown]
# ###text loader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('/content/National AI Policy Consultation Draft V1 (1).txt')
data = loader.load()

# %%
len(data)
# Out:
# 1

# %%
data

# %% [markdown]
# ###Docs loader

# %%
# !pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3959 sha256=c7f3baa7aa8755333047b92b42e679a2f47fd7ba479ca91eb050e9a1839cc9b5
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
from langchain_community.document_loaders import Docx2txtLoader
loader = Docx2txtLoader('/content/National AI Policy Consultation Draft V1 (1).docx')
doc_data = loader.load()

# %%
doc_data

# %%
from langchain_community.document_loaders import DOC2txtLoader
loader = Doc2txtLoader('/content/urdu-all-about-artificial-intelligence-information-for-parents-and-caregivers.docx')
doc1_data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-d6c61f9a7f3b> in <cell line: 1>()
# ----> 1 from langchain_community.document_loaders import DOC2txtLoader
#       2 loader = Doc2txtLoader('/content/urdu-all-about-artificial-intelligence-information-for-parents-and-caregivers.docx')
#       3 doc1_data = loader.load()
#
# ImportError: cannot import name 'DOC2txtLoader' from 'langchain_community.document_loaders' (/usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...
